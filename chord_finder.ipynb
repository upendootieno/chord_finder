# %%
import librosa
import numpy as np

# %%
audio_path ="samples/luke_read_the_room.m4a"
y,sr =librosa.load(audio_path,sr=22050, mono=True)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_19376\4233693920.py:2: UserWarning: PySoundFile failed. Trying audioread instead.
#   y,sr =librosa.load(audio_path,sr=22050, mono=True)
# C:\Users\ADMIN\chord_finder\.env\Lib\site-packages\librosa\core\audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# ---------------------------------------------------------------------------
# LibsndfileError                           Traceback (most recent call last)
# File ~\chord_finder\.env\Lib\site-packages\librosa\core\audio.py:176, in load(path, sr, mono, offset, duration, dtype, res_type)
#     175 try:
# --> 176     y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     178 except sf.SoundFileRuntimeError as exc:
#     179     # If soundfile failed, try audioread instead
#
# ...
